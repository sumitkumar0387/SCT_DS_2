# %% [markdown]
# # SkillCraft Technology Internship - Task 02
# ### Title: Titanic Dataset - Data Cleaning and EDA
# **Created by:** Sumit Kumar
#
# **Date:** 01-August-2025

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("../data/Titanic_data.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 118.9 KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop(columns=["Cabin"],inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
int(df["Age"].median())
# Out:
# 28

# %%
df["Age"]=df["Age"].fillna(df["Age"].median())

# %%
df["Age"]=df["Age"].astype(int)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
df["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
df[df["Embarked"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex  Age  SibSp  Parch  Ticket  Fare Embarked
# 61   female   38      0      0  113572  80.0      NaN
# 829  female   62      0      0  113572  80.0      NaN

# %%
df["Embarked"].mode().iloc[0]
# Out:
# 'S'

# %%
df["Embarked"]=df["Embarked"].fillna(df["Embarked"].mode().iloc[0])

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df["Survived"]=df["Survived"].map({0:"No",1:"Yes"})

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0              1       No       3
# 1              2      Yes       1
# 2              3      Yes       3
# 3              4      Yes       1
# 4              5       No       3
# ..           ...      ...     ...
# 886          887       No       2
# 887          888      Yes       1
# 888          889       No       3
# 889          890      Yes       1
# 890          891       No       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    str
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          891 non-null    int64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    str
# dtypes: float64(1), int64(5), str(5)
# memory usage: 113.2 KB

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df["Embarked"]=df["Embarked"].map({"S":"Southampton","C":"Cherbourg","Q":"Queenstown"})

# %%
df["Embarked"].value_counts()
# Out:
# Embarked
# Southampton    646
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
df.to_csv("titanic_cleaned.csv", index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

# %%
df=pd.read_csv("titanic_cleaned.csv")
df
# Out:
#      PassengerId Survived  Pclass  \
# 0              1       No       3
# 1              2      Yes       1
# 2              3      Yes       3
# 3              4      Yes       1
# 4              5       No       3
# ..           ...      ...     ...
# 886          887       No       2
# 887          888      Yes       1
# 888          889       No       3
# 889          890      Yes       1
# 890          891       No       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
df.shape
# Out:
# (891, 11)

# %%
df.columns.tolist()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Embarked']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    str
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          891 non-null    int64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    str
# dtypes: float64(1), int64(5), str(5)
# memory usage: 121.4 KB

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df["Survived"].value_counts()
# Out:
# Survived
# No     549
# Yes    342
# Name: count, dtype: int64

# %%
df["Survived"].unique()
# Out:
# <ArrowStringArray>
# ['No', 'Yes']
# Length: 2, dtype: str

# %%
df.groupby(['Sex', 'Survived'], dropna=False).size().unstack(fill_value=0)
# Out:
# Survived   No  Yes
# Sex
# female     81  233
# male      468  109

# %%
df.groupby(["Sex","Survived"]).size()
# Out:
# Sex     Survived
# female  No           81
#         Yes         233
# male    No          468
#         Yes         109
# dtype: int64

# %%
df["Embarked"].value_counts()
# Out:
# Embarked
# Southampton    646
# Cherbourg      168
# Queenstown      77
# Name: count, dtype: int64

# %%
sns.countplot(x="Survived",data=df,palette='colorblind')
plt.title("Survival Count")
plt.xlabel("Survived")
plt.ylabel("Count")
plt.show()
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_18112\1982993485.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="Survived",data=df,palette='colorblind')

# %% [markdown]
# ####

# %%
categorical_column=["Sex","Pclass","Embarked"]
for col in categorical_column:
    sns.countplot(x=col,data=df)
    plt.title(f'{col} Distribution')
    plt.xlabel(col)
    plt.ylabel("count")
    plt.show()

# %%
import warnings

warnings.filterwarnings("ignore", category=FutureWarning)

# %%
numerical_column=["Age","Fare"]
for col in numerical_column:
    sns.histplot(df[col],kde=True,color="Brown")
    plt.title(f"{col} Distribution")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
sns.countplot(x='Sex',hue="Survived",data=df,palette='Set2')
plt.title("Survival by Sex")
plt.show()

# %%
sns.countplot(x="Pclass",hue="Survived",data=df)
plt.title("Survival count by Passenger Class")
plt.show()

# %%
sns.countplot(x="Embarked",hue="Survived",data=df)
plt.title("Survival count by Embarkation Port")
plt.show()

# %%
sns.histplot(data=df, x='Age', hue='Survived', multiple='stack', bins=30)
plt.title("Age Distribution by Survival")
plt.show()

# %%
sns.boxplot(x='Survived', y='Fare',hue="Survived",data=df)
plt.title("Fare Distribution by Survival")
plt.xlabel("Survived")
plt.ylabel("Fare")
plt.show()

# %%
sns.catplot(x='Pclass', hue='Survived', col='Sex', data=df, kind='count')
plt.suptitle("Survival Count by Sex and Passenger Class", y=1.25)
plt.show()

# %%
sns.scatterplot(x='Age', y='Fare', hue='Survived', data=df)
plt.title("Age vs Fare by Survival")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.show()

# %%
sns.boxplot(x='Pclass', y='Fare', hue='Survived', data=df)
plt.title("Fare Distribution by Class and Survival")
plt.xlabel("Passenger Class")
plt.ylabel("Fare")
plt.show()

# %% [markdown]
# # ✅ Final Insights from Titanic Dataset
#
# ---
#
# ## 1. Survival Rate
#
# - A significant portion of passengers did **not survive**.
# - **Females** had a much higher survival rate than males, showing that **gender played a crucial role** in survival.
#
# ---
#
# ## 2. Passenger Class Impact
#
# - **First-class** passengers had the **highest survival rates**.
# - **Third-class** passengers had the **lowest**, indicating **socio-economic status influenced outcomes**.
#
# ---
#
# ## 3. Embarkation Port
#
# - Most passengers boarded from **Southampton**.
# - **Cherbourg** passengers showed a **relatively higher survival proportion**.
#
# ---
#
# ## 4. Age Distribution
#
# - **Younger passengers**, especially **children**, had better chances of survival.
# - The **20–40** age group was the **most common** on board.
#
# ---
#
# ## 5. Fare and Survival
#
# - Passengers who paid **higher fares** had better survival rates.
# - Again, this reflects the **advantage of wealth/class**.
#
# ---
#
# ## 6. Gender and Class Combined
#
# - **Female passengers in first and second class** had the **highest survival rates**.
# - **Male passengers in third class** were the **least likely to survive**.
#
# ---
#
# ## 7. Missing Data Handling
#
# - The **‘Cabin’** column was **dropped** due to too many missing values.
# - **Median imputation** was used for missing **‘Age’** values.
# - **‘Embarked’** column’s missing values were **filled with the mode**.
#
# ---
#
# ## 8. Visualization Summary
#
# - **Count plots** and **histograms** helped identify patterns in **categorical and numerical** variables.
# - **Box plots** revealed **fare distribution** differences between survivors and non-survivors.
# - **Scatter plots** and **cat plots** provided deeper insights into **multi-variable relationships**.
#
# ---
#
# ### 📌 These insights help in understanding the key factors that influenced survival during the Titanic disaster, laying the foundation for predictive modeling.
